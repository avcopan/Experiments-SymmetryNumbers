# %%
import pandas as pd
from _pandas_patcher import patchPandas
from rdkit import Chem
from stereomolgraph import StereoMolGraph
from stereomolgraph.algorithms.symmetry import topological_symmetry_number
from stereomolgraph.ipython import View2D

View2D.show_h = True
View2D.show_atom_numbers = False
View2D.generate_bond_orders = False

patchPandas()

# %%
smiles = [
    "C1[C@H]2[C@H]3[C@@H]4[C@H]1[C@@H]4[C@@H]23",
    "[C@@H]12[C@H]3[C@H]4[C@@H]1[C@@H]5[C@H]4[C@H]3[C@H]25",
    "[C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@]1(CCC2)CCC6",
    "[C@]12(CCC3)[C@]3(CCC4)[C@]4(CCC5)[C@@]65[C@@]1(CCC2)CCC6",
    "[C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@@]1(CCC2)CCC6",
    "[C@@]12(CCC3)[C@]3(CCC4)[C@@]4(CCC5)[C@]65[C@@]1(CCC2)CCC6",
    "F[C@H]1C[C@@H](F)C[C@@H](F)C1",
    "F[C@@H]1C[C@@H](F)C[C@@H](F)C1",
    "F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F",
    "F[C@H]1[C@@H](F)[C@H](F)[C@H](F)[C@H](F)[C@H]1F",
    "F[C@H]1[C@@H](F)C[C@@H](F)[C@@H](F)C1",
    "F[C@H]1[C@H](F)C[C@@H](F)[C@H](F)C1",
    "F[C@H]1[C@H](F)C[C@H](F)[C@@H](F)C1",
    "F[C@H]1[C@@H](F)C[C@H](F)[C@H](F)C1",
    "F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F",
]

# %%
rows = []
for smiles_string in smiles:
    rdmol = Chem.MolFromSmiles(smiles_string, sanitize=False)
    rdmol.UpdatePropertyCache(strict=True)
    rdmol = Chem.AddHs(rdmol)
    Chem.SanitizeMol(rdmol)

    graph = StereoMolGraph.from_rdmol(rdmol, stereo_complete=True)
    rows.append(
        {
            "StereoMolGraph": graph,
            "top_sym_num": topological_symmetry_number(graph),
            "input_smiles": smiles_string,
        }
    )

df_smiles_symmetry = pd.DataFrame(rows)
df_smiles_symmetry
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 12
#       8     graph = StereoMolGraph.from_rdmol(rdmol, stereo_complete=True)
#       9     rows.append(
#      10         {
#      11             "StereoMolGraph": graph,
# ---> 12             "top_sym_num": topological_symmetry_number(graph),
#      13             "input_smiles": smiles_string,
#      14         }
#      15     )
#
# File ~\Code\packages\StereoMolGraph\src\stereomolgraph\algorithms\symmetry.py:115, in topological_symmetry_number(graph, atom_labels)
#     110     atom_labels = color_refine_smg(graph, atom_labels=atom_labels)
#     112 mappings = vf2pp_all_isomorphisms(
#     113     graph, graph, stereo=True, atom_labels=(atom_labels, atom_labels)
#     114 )
# --> 115 return deque(enumerate(mappings, 1), maxlen=1)[0][0]
#
# File ~\Code\packages\StereoMolGraph\src\stereomolgraph\algorithms\isomorphism.py:318, in vf2pp_all_isomorphisms(g1, g2, atom_labels, stereo, stereo_change, subgraph)
#     285 def vf2pp_all_isomorphisms(
#     286     g1: MolGraph
#     287     | StereoMolGraph
#    (...)    301     subgraph: bool = False,
#     302 ) -> Iterator[dict[AtomId, AtomId]]:
#     303     r"""Find all isomorphisms between two graphs.
#     304
#     305     Defined in: https://doi.org/10.1021/acs.jcim.5c02523
#    (...)    316              dictionary mapping atom ids of g1 to atom ids of g2.
#     317     """
# --> 318     if params_state := _sanity_check_and_init(
#     319         g1, g2, atom_labels, stereo, stereo_change, subgraph
#     320     ):
#     321         params, state = params_state
#     322     else:
#
# File ~\Code\packages\StereoMolGraph\src\stereomolgraph\algorithms\isomorphism.py:191, in _sanity_check_and_init(g1, g2, atom_labels, stereo, stereo_change, subgraph)
#     188 else:
#     189     g1_labels, g2_labels = atom_labels
# --> 191 g1_labels_counter = Counter(g1_labels.values())
#     192 g2_labels_counter = Counter(g2_labels.values())
#     194 if not subgraph and g1_labels_counter != g2_labels_counter:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
